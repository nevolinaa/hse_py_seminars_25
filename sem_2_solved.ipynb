# %% [markdown]
# # Программирование на Python
#
# # Семинар 2. Цикл while

# %% [markdown]
# ## Содержание
# 0. [Введение](#par0)
#    1. [Повторение](#par0.1)
#    2. [Введение в циклы](#par0.2)
# 1. [Цикл while с условием](#par1)
#    1. [Синтаксис](#par1.1)
#    2. [Цыганские фокусы](#par1.2)
# 2. [Цикл while True. Оператор break](#par2)
# 3. [Вложенные циклы](#par3)
# 4. [Цикл for. Начало](#par4)

# %% [markdown]
# ## Введение <a name="par0"></a>
# ### Повторение <a name="par0.1"></a>

# %% [markdown]
# <img src="images/sem_2_2.jpg" alt="Начинаем" width="400">

# %% [markdown]
# <img src="images/sem_2_0.png" alt="Тест 1" width="800">

# %% [markdown]
# <img src="images/sem_2_1.png" alt="Тест 2" width="800">

# %% [markdown]
# <img src="images/sem_2_6.png" alt="Тест 2" width="800">

# %% [markdown]
# Мы пока не изучили списки, однако дам подсказку: проверить, есть ли элемент в списке, можно с помощью оператора `in`
#
# - как думаете, как он работает, например, со строками?
# - а как проверить, что элемента в списке нет?

# %%
dollars = ['Турция', 'ОАЭ', 'Канада', 'Сингапур']
euro = ['Италия', 'Сингапур', 'Франция', 'Турция', 'ОАЭ']

both = 'В выбранной стране можно использовать и доллары, и евро'
no = 'Лучше использовать местную валюту'

# ваш код ниже
country = input()
if country in dollars and country in euro:
    print(both)
else:
    print(no)
# Out:
# Сингапур
# В выбранной стране можно использовать и доллары, и евро

# %% [markdown]
# ### Введение в циклы <a name="par0.2"></a>

# %% [markdown]
# Циклы повсюду в нашей жизни. Давайте посмотрим на несколько примеров:
#
# - Вы пьете кофе, пока не почувствуете себя бодрым
# - Вы смотрите серию за серией, пока не закончите сезон (или пока не кончатся новогодние праздники)
# - Вы обещаете себе начать что-то "с понедельника", но понедельник никак не наступает

# %% [markdown]
# <div style="display: flex;">
#   <img src="images/sem_2_3.jpg" alt="Циклы 1" width="35%">
#   <img src="images/sem_2_4.jpg" alt="Циклы 2" width="35%">
# </div>

# %% [markdown]
# **Зачем нужны циклы в программировании?**
#
# - `Автоматизация повторяющихся задач` Например, для каждого студента в аудитории 1) проверить присутствие на паре 2) поставить оценку за активность
# - `Экономия времени и сил` Вместо того чтобы писать один и тот же код много раз, можно использовать цикл
# - `Написание более понятного и компактного кода` (логика та же, что с созданием переменных вместо использования конкретных чисел/строк и т.д.)
#
# **Основные типы циклов в Python**
#
# - Цикл `while` — выполняет код, пока условие истинно
# - Цикл `for` — выполняет код для каждого элемента в последовательности
#
# Начнем с цикла `while`

# %% [markdown]
# ## Цикл while с условием <a name="par1"></a>
#
# ### Синтаксис цикла `while`:   <a name="par1.1"></a>
#
# ```
# while <условие>:
#     <блок кода, который исполняется, пока выполняется логическое условие выше>
# ```
#
# **Помните про отступ!**

# %% [markdown]
# <center><b><font size=4>Задание №0. Это база </font></b></center>
#
# Напишите программу, которая вычисляет сумму чисел от start_number до end_number включительно (где оба числа вводятся пользователем)
#
# **Программа должна использовать цикл while**

# %%
# Запрашиваем у пользователя числа start_number и end_number
start_number = int(input("Введите число, с которого начинаем считать сумму: "))
end_number = int(input("Введите число, на котором заканчиваем считать сумму: "))

# Создаем переменные
i = start_number # счетчик
total_sum = 0    # сюда будем добавлять числа

# Цикл while
while i <= end_number:
    total_sum += i  # Добавляем текущее значение i к сумме
    i += 1          # Увеличиваем счетчик на 1

# Выводим результат
print(f"Сумма чисел от {start_number} до {end_number} равна: {total_sum}")
# Out:
# Введите число, с которого начинаем считать сумму: 4
# Введите число, на котором заканчиваем считать сумму: 6
# Сумма чисел от 4 до 6 равна: 15

# %% [markdown]
# А что будет, если забыть прописать изменение числа-счетчика в цикле?

# %%
# Запрашиваем у пользователя числа start_number и end_number
start_number = int(input("Введите число, с которого начинаем считать сумму: "))
end_number = int(input("Введите число, на котором заканчиваем считать сумму: "))

# Создаем переменные
i = start_number # счетчик
total_sum = 0 # сюда будем добавлять числа

# Цикл while
while i <= end_number:
    total_sum += i  # Добавляем текущее значение i к сумме

# Выводим результат
print(f"Сумма чисел от {start_number} до {end_number} равна: {total_sum}")
# Out:
# Введите число, с которого начинаем считать сумму: 4
# Введите число, на котором заканчиваем считать сумму: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       9 # Цикл while
#      10 while i <= end_number:
# ---> 11     total_sum += i  # Добавляем текущее значение i к сумме
#      13 # Выводим результат
#      14 print(f"Сумма чисел от {start_number} до {end_number} равна: {total_sum}")
#
# KeyboardInterrupt:

# %% [markdown]
# Получаем бесконечный цикл. Но нам нужно было, чтобы он завершился. Мы допустили ошибку
#
# **Чтобы завершить цикл, нажмите на "стоп" - черный квадрат сверху**

# %% [markdown]
# ### Цыганские фокусы. Что можно делать внутри цикла? <a name="par1.2"></a>
#
# Внутри любого цикла мы можем:
# - **проверять различные условия** и выполнять разные действия в зависимости от результатов проверки (используем `if/elif/else`)
# - проверять (не)выполнение **сразу нескольких** условий (`and/or/not`)
# - просить пользователя **вводить** значения (с помощью `input()`)
# - и **выводить** различные значения (через `print()`)
# - и в общем делать все то, что мы изучили на прошлом семинаре)
#
# давайте посмотрим на практике:

# %% [markdown]
# <center><b><font size=4>Задание №1. Угадай число </font></b></center>
#
# - Компьютер загадывает случайное число от 1 до 10
#
# - Пользователь должен угадать это число
# - Он может делать несколько попыток, пока не угадает число. Программа должна писать номер попытки
#
# - Программа должна подсказывать, больше или меньше введенное число по сравнению с загаданным
# - Если пользователь угадывает число, программа поздравляет его и завершает работу

# %%
import random

# Загадываем случайное число от 1 до 10
secret_number = random.randint(1, 10)

# Создаем переменные
user_guess = 0 # Ввод пользователя
trial_num = 0 # Номер попытки

# Пишем цикл while
while user_guess != secret_number:
    trial_num += 1
    user_guess = int(input(f"Угадайте число от 1 до 10. Попытка №{trial_num}: "))
    
    if user_guess < secret_number:
        print("Загаданное число больше!")
    elif user_guess > secret_number:
        print("Загаданное число меньше!")
    else:
        print("Поздравляю! Вы угадали число!")
# Out:
# Угадайте число от 1 до 10. Попытка №1: 5
# Загаданное число больше!
# Угадайте число от 1 до 10. Попытка №2: 7
# Загаданное число больше!
# Угадайте число от 1 до 10. Попытка №3: 9
# Загаданное число меньше!
# Угадайте число от 1 до 10. Попытка №4: 8
# Поздравляю! Вы угадали число!

# %% [markdown]
# <center><b><font size=4>Задание №2. Квест </font></b></center>
#
# Вы находитесь в квесте и должны выполнить два задания:
#
# 1. Найти ключ (ввести "ключ").
# 2. Открыть дверь (ввести "дверь").
#
# Программа будет спрашивать у пользователя, что он хочет сделать, и проверять, выполнены ли оба задания. Если оба задания выполнены, программа поздравляет пользователя и завершает квест.

# %%
# Создаем переменные
has_key = False
door_opened = False

print("Добро пожаловать в квест! Вам нужно найти ключ и открыть дверь.")

# Пишем цикл
while not has_key or not door_opened:
    action = input("Что вы хотите сделать? (найти ключ/открыть дверь): ")
    
    if action == "найти ключ":
        has_key = True
        print("Вы нашли ключ!")
    elif action == "открыть дверь":
        if has_key:
            door_opened = True
            print("Вы открыли дверь!")
        else:
            print("Сначала нужно найти ключ!")
    else:
        print("Неизвестное действие. Попробуйте еще раз.")

print("Поздравляю! Вы завершили квест!")
# Out:
# Добро пожаловать в квест! Вам нужно найти ключ и открыть дверь.
# Что вы хотите сделать? (найти ключ/открыть дверь): открыть дверь
# Сначала нужно найти ключ!
# Что вы хотите сделать? (найти ключ/открыть дверь): ключ
# Неизвестное действие. Попробуйте еще раз.
# Что вы хотите сделать? (найти ключ/открыть дверь): найти ключ
# Вы нашли ключ!
# Что вы хотите сделать? (найти ключ/открыть дверь): открыть дверь
# Вы открыли дверь!
# Поздравляю! Вы завершили квест!

# %% [markdown]
# ## While True и break <a name="par2"></a>
#
# while True — это цикл, который выполняется бесконечно, так как условие True всегда истинно. Чтобы выйти из такого цикла, используется оператор break
#
# ```
# while True:
#     <код>         # Тело цикла
#     if <условие>: # Условие для выхода из цикла
#         break     # Выход
# ```

# %% [markdown]
# <center><b><font size=4>Задание №3. Я опять забыл(а) пароль </font></b></center>
#
# - Вы забыли пароль и у вас есть бесконечное количество попыток, чтобы его вспомнить (эх, если бы это было так...)
# - Если пароль верный, цикл завершается

# %%
# your code here
password = "secret"

while True:
    user_input = input("Введите пароль: ")
    if user_input == password:
        print("Пароль верный! Доступ разрешен.")
        break
    print("Неверный пароль. Попробуйте еще раз.")
print("Больше не забывай :)")
# Out:
# Введите пароль: seeecret
# Неверный пароль. Попробуйте еще раз.
# Введите пароль: secret
# Пароль верный! Доступ разрешен.
# Больше не забывай :)

# %% [markdown]
# ## Вложенные циклы <a name="par3"></a>
#
# Теперь, когда мы шарим за циклы, можем добавить и их в цыганские фокусы! А что это значит?

# %% [markdown]
# <center><b><font size=4>Задание №4. Пирамидка из звездочек </font></b></center>
#
# Нарисуйте с помощью вложенных циклов пирамидку:
# ```
#     *
#    ***
#   *****
#  *******
# *********
# ```
#
#
#
# --------------------------------------
# Подсказка. Вложенные циклы:
# ```
# while <условие>:     # Основной цикл
#     <код>
#     while <условие>: # Вложенный цикл
#         <код>
# ```

# %%
height = int(input('Введите высоту пирамиды: '))

# задайте счетчик для строк
i = 1 

# напишите цикл с вложенным циклом
while i <= height:
    # Печатаем пробелы перед звездочками
    spaces = height - i
    while spaces > 0:
        print(" ", end="")
        spaces -= 1
    
    # Печатаем звездочки
    stars = 2 * i - 1
    while stars > 0:
        print("*", end="")
        stars -= 1
    
    print()  # Переход на новую строку
    # Переход к следующей строке
    i += 1
# Out:
# Введите высоту пирамиды: 9
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************
# *****************

# %% [markdown]
# ## Цикл for. Начало <a name="par4"></a>
#
# Перед тем, как кратко ввести вас в цикл for, еще более кратко введу в списки:
# - Список — это упорядоченная коллекция элементов. Элементы могут быть любого типа: числа, строки, другие списки и т.д.
# - Список задается **квадратными скобками: `[...]`**
#
# Пример списка:
# ```
# fruits = ["яблоко", "банан", "вишня"]
# ```
# - Элементы списка можно **перебирать по одному** (так же, как мы делали со строками на прошлом семинаре. помним, что **нумерация начинается с 0**)
# - Списки используются для хранения и обработки множества данных

# %%
# попробуйте создайте свой список
fruits = ["яблоко", "банан", "вишня"]

# %% [markdown]
# ### Теперь про цикл for.
# `Цикл for` используется для **перебора элементов** в коллекции (например, в списке). Он делает то же самое, что и цикл while, но более удобен для работы с коллекциями элементов
#
# ### Синтаксис цикла `for`:
#
# ```
# for <переменная> in <коллекция>:
#     <блок кода> # Тело цикла
# ```
#
# **И все еще помним про отступ!**

# %%
# попробуйте перебрать список, созданный ранее:

for fruit in fruits:
    print(fruit)
# Out:
# яблоко
# банан
# вишня

# %% [markdown]
# <center><b><font size=4>Задание №5. Генератор никнеймов </font></b></center>
#
# Напишите программу, которая:
# - Спрашивает у пользователя его имя
# - Использует цикл for для перебора списка прилагательных и создания никнейма
# - Выводит несколько вариантов никнеймов

# %%
# Ввод имени от пользователя
name = input("Введите ваше имя: ")

# Список прилагательных для генерации никнеймов
adjectives = ["Смелый", "Веселый", "Ловкий", "Мудрый", "Яркий", "Неуловимый", "Таинственный"]

# Цикл for для создания никнеймов
print("Ваши варианты никнеймов:")
for adj in adjectives:
    print(f"{adj} {name}")
# Out:
# Введите ваше имя: Ковальски
# Ваши варианты никнеймов:
# Смелый Ковальски
# Веселый Ковальски
# Ловкий Ковальски
# Мудрый Ковальски
# Яркий Ковальски
# Неуловимый Ковальски
# Таинственный Ковальски

# %% [markdown]
# ### Итак, циклы  `while ` и  `for ` очень похожи
# - они повторяют одни и те же действия несколько раз
# - при этом мы можем использовать вместе с циклами все наши любимые цыганские фокусы :)
# - и даже делать циклы в цикле (да, для  `for ` тоже!)
#
# ```
# for <элемент> in <коллекция>:     # Основной цикл
#     <код>
#     for <элемент> in <коллекция>: # Вложенный цикл
#         <код>
# ```
#
# ### Чем же отличаются цикл while и for?

# %% [markdown]
# | **Цикл `while`**                  | **Цикл `for`**                        |
# |:---------------------------------:|:-------------------------------------:|
# | Используется, когда количество итераций неизвестно | Используется для перебора коллекций |
# | Требует прерывания вручную (через изменение условия или `break`)| Автоматически перебирает элементы и останавливается   |
# | Пример: `while x < 10:`           | Пример: `for i in ['apple', 'banana', 'cherry']:`        |
#
#
# Продолжение следует...
#
# <img src="images/sem_2_5.jpg" alt="Начинаем" width="400">
