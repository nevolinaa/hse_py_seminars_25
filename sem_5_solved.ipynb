# %% [markdown]
# # Программирование на Python
#
# # Семинар 5. Вложенные структуры данных. Сортировки

# %% [markdown]
# ## Содержание
#
# 1. [Повторение. Типы данных. Множества и словари](#par0)
# 2. [Сортировки](#par1)
# 3. [Минимум, максимум](#par2)
# 4. [Вложенные структуры данных](#par3)

# %% [markdown]
# <img src="images/sem_5_6.jpg" alt="Введение" width="500">

# %% [markdown]
# ## **Повторение. Типы данных. Множества и словари** <a name="par0"></a>
#
# | Неизменяемые типы данных | Изменяемые типы данных |
# | --- | --- |
# | кортеж | список |
# | строки | множество |
# | числа целые и вещественные | словарь |
# | логические переменные | |

# %% [markdown]
# | Как мы их называем | Как они называютcя по-английски | Как они называются в Python |
# | :- | :- | :- |
# | **Естественные типы данных** | | |
# | целое число | integer | `int` |
# | вещественное число | floating-point number | `float` |
# | логическая переменная | boolean / logical | `bool` |
# | **Упорядоченные типы данных (последовательности)** | | |
# | строка | string | `str` |
# | список | list | `list` |
# | кортеж | tuple | `tuple` |
# | **Неупорядоченные типы данных (коллекции)** | | |
# | множество | set | `set` |
# | словарь | dictionary | `dict` |

# %% [markdown]
# | Тип данных | Тип структуры данных | Как обращаемся к элементу внутри? |
# | --- | --- | --- |
# | кортежи | упорядоченный | по индексу |
# | списки |  упорядоченный | по индексу |
# | строки  | упорядоченный | по индексу |
# | множество | неупорядоченный | не можем обратиться к элементу |
# | Словари | неупорядоченный | по ключу |

# %% [markdown]
# <center><b><font size=4>Задание с НЭ: B02</font></b></center>
#
# <img src="images/sem_5_2.png" alt="Задание с НЭ 2" width="800">

# %% [markdown]
# <center><b><font size=4>Задание с НЭ: B04</font></b></center>
#
# <img src="images/sem_5_1.jpeg" alt="Задание с НЭ B04" width="800">

# %% [markdown]
# | Ввод                                      | Результат              |
# |-------------------------------------------|------------------------|
# | ВК, Сбербанк <br> ПИК, Тинькофф, Сбербанк <br> Тинькофф, ПИК, ВК, Перекресток | ПИК, Тинькофф |
# | ПИК, Сбербанк, Тинькофф, Альфа <br> ВК, ПИК, Самолет, Яндекс, ВТБ, Альфа <br> Альфа, ПИК | |
# | Сбербанк, Тинькофф <br> ВК, ПИК, Самолет, Яндекс, ВТБ, Альфа <br> Альфа, ПИК, Самолет | Альфа, ПИК, Самолет |

# %%
# Получаем на вход три списка компаний, разделенных запятой и пробелом
# И создаем set, чтобы можно было использовать операции над множествами
in_top_10 = set(input().split(', '))
python_usage = set(input().split(', '))
paid_internship = set(input().split(', '))

# с оплачиваемой стажировкой, не входят в топ-10 работодателей и в которых надо работать с использованием Python
needed_companies = (paid_internship - in_top_10) & python_usage

# или в другом порядке: paid_internship & python_usage - in_top_10
# или paid_internship.difference(in_top_10).intersection(python_usage)

# нужно вывести в алфавитном порядке
needed_companies = sorted(needed_companies)

# нужно вывести через запятую и пробел
needed_companies = ", ".join(needed_companies)
print(needed_companies)
# Out:
# Сбербанк, Тинькофф
# ВК, ПИК, Самолет, Яндекс, ВТБ, Альфа
# Альфа, ПИК, Самолет
# Альфа, ПИК, Самолет

# %% [markdown]
# <center><b><font size=4>Задание с НЭ: B05</font></b></center>
#
# <img src="images/sem_5_3.png" alt="Задание с НЭ 2" width="800">

# %% [markdown]
# | Ввод                                      | Результат              |
# |-------------------------------------------|------------------------|
# | 0 | Мостелеком<br>МТТС<br>Трилайн |
# | 3 | Трилайн |

# %%
internet = {'Мостелеком': [1, 2, 1, 1, 1, 2, 1], 
            'Соединение2023': [1, 1, 0, 1, 1, 1, 0], 
            'МТТС': [1, 1, 1, 1, 2, 1, 1], 
            'Трилайн': [2, 2, 1, 1, 1, 2, 2]}

# Получаем на вход минимально допустимое количество дней 
# со скоростью выше заявленной и преобразуем в число
speed_threshold = int(input())

# Проходимся по ключам (чтобы выводить название оператора при соблюдении условия)
# и значениям (чтобы проверять соблюдение условия) словаря 

for provider, speeds in internet.items():
    
    # нет дней с понижением скорости (понижение - это 0): 0 not in
    # и количество дней со скоростью выше заявленной не менее допустимого
    # (выше заявленой - это 2). количество считаем через count: speeds.count(2)
    
    if 0 not in speeds and speeds.count(2) >= speed_threshold:
        print(provider)
# Out:
# 3
# Трилайн

# %%
# или можно проходиться просто по ключам:
for provider in internet.keys():
    if 0 not in internet[provider] and internet[provider].count(2) >= speed_threshold:
        print(provider)
# Out:
# Трилайн

# %% [markdown]
# <img src="images/sem_5_0.jpeg" alt="Начинаем" width="400">

# %% [markdown]
# ## **Сортировки** <a name="par1"></a>
#
# ```python
# # Сортировка списка чисел - по возрастанию
# numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5]
# sorted_numbers = sorted(numbers)
# print(sorted_numbers)  # [1, 1, 2, 3, 4, 5, 5, 6, 9]
#
# # Сортировка списка строк - по алфавиту
# fruits = ['apple', 'banana', 'cherry', 'date']
# sorted_fruits = sorted(fruits)
# print(sorted_fruits)  # ['apple', 'banana', 'cherry', 'date']
#
# # Сортировка с использованием параметра key
# # Например, по длине строки
# sorted_fruits_by_length = sorted(fruits, key=len)
# print(sorted_fruits_by_length)  # ['date', 'apple', 'banana', 'cherry']
#
# # Порядок сортировки: в обратном порядке
# sorted_numbers_desc = sorted(numbers, reverse=True)
# print(sorted_numbers_desc)  # [9, 6, 5, 5, 4, 3, 2, 1, 1]
# ```

# %% [markdown]
# ## **Минимум, максимум** <a name="par2"></a>
#
# ```python
# # Нахождение минимального и максимального числа
# numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5]
# min_number = min(numbers)
# max_number = max(numbers)
# print(min_number)  # 1
# print(max_number)  # 9
#
# # Нахождение минимальной и максимальной строки (лексикографический порядок)
# fruits = ['apple', 'banana', 'cherry', 'date']
# min_fruit = min(fruits)
# max_fruit = max(fruits)
# print(min_fruit)  # 'apple'
# print(max_fruit)  # 'date'
#
# # Использование параметра key
# # Нахождение строки с минимальной и максимальной длиной
# min_fruit_by_length = min(fruits, key=len)
# max_fruit_by_length = max(fruits, key=len)
# print(min_fruit_by_length)  # 'date'
# print(max_fruit_by_length)  # 'banana'
# ```

# %% [markdown]
# <center><b><font size=4>Задача 1: Соревнование по полетам</font></b></center>
#
# <img src="images/sem_5_5.jpg" alt="Полеты" width="500">
#
# В стране фей барби провели соревнование по скоростным полетам. Данные о результатах соревнования по полетам на 100 метров представлены в виде словаря, где каждый ключ соответствует списку значений:
# - **name** — имя участника,
# - **age** — возраст участника,
# - **time** — время полета в секундах
#
# ```python
# competition = {
#     "name": ["Азура", "Нори", "Элина", "Далия", "Топаз"],
#     "age": [25, 18, 22, 28, 24],
#     "time": [12.5, 11.8, 13.1, 11.5, 12.9]
# }
#
# Также для вашего удобства создан список данных участник - время:
#
# participants = [
#     ('Азура', 12.5),
#     ('Нори', 11.8),
#     ('Элина', 13.1),
#     ('Далия', 11.5),
#     ('Топаз', 12.9)
# ]
# ```
#
# ### Задания:
# 1. Выведите **топ участников** залета (от самого быстрого к самому медленному)
# 2. Найдите **победителя** залета (участника, который пролетел быстрее всех)
# 3. Найдите возраст **самого молодого и самого взрослого** участников
# 4. Рассчитайте **среднее время залета** участников

# %%
competition = {
    "name": ["Азура", "Нори", "Элина", "Далия", "Топаз"],
    "age": [25, 30, 22, 28, 24],
    "time": [12.5, 11.8, 13.1, 11.5, 12.9]
}

participants = list(zip(competition["name"], competition["time"]))

# 1. Топ участников залета (от быстрого к медленному)
participants_top = sorted(participants, key=lambda x: x[1]) 
# lambda x: x пока понимать не нужно. главное принцип работы sorted с key понять

print("Топ участников забега:")
for participant in participants_top:
    print(f"{participant[0]} — {participant[1]} сек.")

# 2. Победитель залета (наименьшее время) 
winner_time = min(competition["time"])
winner_index = competition["time"].index(winner_time)
winner = competition["name"][winner_index]
print(f"\nПобедитель {winner} с результатом {winner_time} сек.")

# 3. Возраст самого молодого и самого взрослого участника
youngest = min(competition["age"])
oldest = max(competition["age"])

print(f"\nСамому молодому участнику - {youngest}, а взрослому - {oldest} лет")

# 4. Среднее время участников залета
average_time = sum(competition["time"]) / len(competition["time"])
print(f"\nСреднее время участников залета - {average_time:.2f} сек.")
# Out:
# Топ участников забега:
# Далия — 11.5 сек.
# Нори — 11.8 сек.
# Азура — 12.5 сек.
# Топаз — 12.9 сек.
# Элина — 13.1 сек.
#
# Победитель Далия с результатом 11.5 сек.
#
# Самому молодому участнику - 22, а взрослому - 30 лет
#
# Среднее время участников залета - 12.36 сек.

# %% [markdown]
# ## **Вложенные структуры данных** <a name="par3"></a>

# %% [markdown]
# ### Списки списков
#
# Каждый элемент списка сам является списком. Это удобно для представления таблиц, матриц или многомерных данных.
#
# ```python
# matrix = [
#     [1, 2, 3],
#     [4, 5, 6],
#     [7, 8, 9]
# ]
# ```
#
# #### Основные операции:
# - **Доступ к элементу**: `matrix[0][1]` (это 2).
# - **Итерация по элементам**:
# ```python
# for row in matrix:
#     for element in row:
#         print(element)
# ```
#
# ### Вложенные структуры данных: словари словарей
#
# ```python
# users = {
#     "Alice": {"age": 25, "city": "New York"},
#     "Bob": {"age": 30, "city": "London"},
#     "Charlie": {"age": 22, "city": "Paris"}
# }
# ```
#
# Словари словарей — это структура, где значения словаря сами являются словарями. Это полезно для хранения сложных данных, например, информации о пользователях, где каждый пользователь описывается несколькими характеристиками.
#
# #### Основные операции:
# - **Доступ к элементу**: `users["Alice"]["age"]` (это 25).
# - **Добавление нового пользователя**:
# ```python
# users["Diana"] = {"age": 28, "city": "Berlin"}
# ```
# - **Итерация по элементам**:
# ```python
# for name, info in users.items():
#     print(f"{name}: {info['age']} лет, город {info['city']}")
# ```
#
# ### Комбинации списков и словарей
#
# Часто данные представляются в виде комбинаций списков и словарей. Например, список словарей или словарь списков.
#
# #### Пример 1: Список словарей
#
# ```python
# participants = [
#     {"name": "Alice", "age": 25, "time": 12.5},
#     {"name": "Bob", "age": 30, "time": 11.8},
#     {"name": "Charlie", "age": 22, "time": 13.1}
# ]
# ```
#
# #### Основные операции:
# - **Доступ к элементу**: `participants[0]["name"]` (это "Alice").
# - **Сортировка по ключу**:
# ```python
# sorted_participants = sorted(participants, key=lambda x: x["time"])
# ```
#
# #### Пример 2: Словарь списков
#
# ```python
# data = {
#     "names": ["Alice", "Bob", "Charlie"],
#     "ages": [25, 30, 22],
#     "times": [12.5, 11.8, 13.1]
# }
# ```
#
# #### Основные операции:
# - **Доступ к элементу**: `data["names"][0]` (это "Alice").
# - **Итерация по данным**:
# ```python
# for i in range(len(data["names"])):
#     print(f"{data['names'][i]}, возраст {data['ages'][i]}, время {data['times'][i]}")
# ```
#
# ### Вложенные структуры: словари списков словарей
#
# Иногда данные могут быть ещё более сложными. Например, словарь, где значения — это списки словарей.
#
#
# ```python
# teams = {
#     "Team A": [
#         {"name": "Alice", "score": 10},
#         {"name": "Bob", "score": 15}
#     ],
#     "Team B": [
#         {"name": "Charlie", "score": 12},
#         {"name": "Diana", "score": 8}
#     ]
# }
# ```
#
# ### Когда использовать вложенные структуры?
#
# - **Списки списков**: для таблиц, матриц, сеток
# - **Словари словарей**: для хранения сложных объектов с множеством характеристик (например, пользователи, товары)
# - **Список словарей**: для хранения однотипных объектов (например, участники соревнования)
# - **Словарь списков**: для группировки данных (например, данные по командам)
# - **Сложные вложенные структуры**: для представления иерархических данных (например, данные сотрудников компании)

# %% [markdown]
# <center><b><font size=4>Задача 2: Подработка в библиотеке</font></b></center>
#
# <img src="images/sem_5_4.jpg" alt="Библиотека" width="500">
#
# Барби провинилась и ее оставили работать в библиотеке после уроков. Ей нужно провести ревизию книг
#
# ### Задания:
# 0. Создайте переменную, которая будет хранить информацию о книгах, авторах и читателях:
#
# | Название книги              | Автор              | Год издания | Читатели |
# |-----------------------------|--------------------|-------------|----------|
# | "Барби и мир"               | "Лев Стройный"     |     1867    |    []    |
# | "Унесенные крыльями"        | "Барбарет Митбелл" |     1936    |    []    |
# | "Цвет фуксия"               | "Элис Бокер"       |     1982    |    []    |
# | "О дивная новая кукла"      | "Ньюолс Хаксли"    |     1932    |    []    |
# | "Барби и принцесса нищенка" | "Кейт Роулинг"     |     1997    |    []    |
#
# 1. Узнайте, кто читал каждую из книг, занесите читателей в списки
#
# | Название книги              | Пример ввода читателей    |
# |-----------------------------|---------------------------|
# | "Барби и мир"               | Женевьева, Луи, Майя      |
# | "Унесенные крыльями"        | Биббл, Дженни, Челси      |
# | "Цвет фуксия"               | Дива, Талула              |
# | "О дивная новая кукла"      | Альберт                   |
# | "Барби и принцесса нищенка" | Патрисия, Бриетта, Феникс |
#
# 2. Подготовьте статистику:
#   - сколько всего книг хранится в библиотеке
#   - сколько книг хранится в библиотеке у каждого автора
#   - сколько читателей у каждой книги, какие книги самые популярные и непопулярные

# %%
# Создайте переменную, которая будет хранить информацию о книгах, авторах и читателях
# Подсказка: нужны вложенные структуры данных
library = {
    "Барби и мир": {"author": "Лев Стройный", "year": 1867, "readers": []},
    "Унесенные крыльями": {"author": "Барбарет Митбелл", "year": 1936, "readers": []},
    "Цвет фуксия": {"author": "Элис Бокер", "year": 1982, "readers": []},
    "О дивная новая кукла": {"author": "Ньюолс Хаксли", "year": 1932, "readers": []},
    "Барби и принцесса нищенка": {"author": "Кейт Роулинг", "year": 1997, "readers": []},
}

# Занесите читателей в списки (читатели подаются на вход через запятую и пробел)
for book in library.keys():
    readers = input(f'Введите читателей книги {book}: ').strip().split(', ')
    library[book]["readers"].extend(readers) # extend так как добавляем несколько элементов в список
print('')

# Статистика: сколько читателей у каждой книги
for book in library.keys():
    print(f'Количество читателей книги "{book}": {len(library[book]["readers"])}')

# Статистика: самая популярная и непопулярная книги
most_popular_book = max(library.keys(), key=lambda book: len(library[book]["readers"]))
least_popular_book = min(library.keys(), key=lambda book: len(library[book]["readers"]))
# lambda используем просто по аналогии, вникать пока не нужно
# цель снова понять принцип работы key, в этот раз в сочетании с min/max

print(f'\nСамая популярная книга - "{most_popular_book}", самая непопулярная - "{least_popular_book}"')
# Out:
# Введите читателей книги Барби и мир: Женевьева, Луи, Майя
# Введите читателей книги Унесенные крыльями: Биббл, Дженни, Челси
# Введите читателей книги Цвет фуксия: Дива, Талула
# Введите читателей книги О дивная новая кукла: Альберт
# Введите читателей книги Барби и принцесса нищенка: Патрисия, Бриетта, Феникс
#
# Количество читателей книги "Барби и мир": 3
# Количество читателей книги "Унесенные крыльями": 3
# Количество читателей книги "Цвет фуксия": 2
# Количество читателей книги "О дивная новая кукла": 1
# Количество читателей книги "Барби и принцесса нищенка": 3
#
# Самая популярная книга - "Барби и мир", самая непопулярная - "О дивная новая кукла"

# %% [markdown]
# <img src="images/sem_5_7.jpg" alt="пока-пока" width="400">
